# %% [markdown]
# <a href="https://colab.research.google.com/github/saraswathykrk/ml_projects/blob/main/SMS_Notifications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("request")
# install.packages("hash")
# library(httr)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependency ‘lazyeval’
#
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/lazyeval_0.2.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 83482 bytes (81 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# Calling the URL and assigning it to variable named url
# %%R
url = paste0("https://www.fast2sms.com/dev/bulk")


# Initializing the payload
# In <number1>,<number2> pass the mobile number
# In <Type Your Message> pass the message
payload = paste0("sender_id=FSTSMS&message=Project Name : <Your Project Name> Project deadline : Date & time Note: Check email for more details.&language=english&route=p&numbers=9833835156,9019686176")

# initializing the POST method
response <- POST(url,
                 body = payload,
                 add_headers('authorization'= "rNS1cnUmiVpZH9XtGfk3bMJvRyAzeoTwQEOFK8C065glhsdB42UA0bkoRKfLcVYh9i1lxaJdwpsnBr8E",
                             'Cache-Control' = 'no-cache',
                             'Content-Type' = "application/x-www-form-urlencoded"),
                 encode = "json",
                 verbose())
# Out:
# R[write to console]: -> POST /dev/bulk HTTP/1.1
# -> Host: www.fast2sms.com
# -> User-Agent: libcurl/7.58.0 r-curl/4.3.2 httr/1.4.3
# -> Accept-Encoding: deflate, gzip
# -> Cookie: XSRF-TOKEN=%3D%3D; laravel_session=
# -> Accept: application/json, text/xml, application/xml, */*
# -> authorization: rNS1cnUmiVpZH9XtGfk3bMJvRyAzeoTwQEOFK8C065glhsdB42UA0bkoRKfLcVYh9i1lxaJdwpsnBr8E
# -> Cache-Control: no-cache
# ...

# %%
import requests

# %%
# Initializing the request type
request = "https://www.fast2sms.com/dev/bulkV2"

# Initializing the sender ID
sender_id = "?sender_id=TXTIND"

# Initializing the message; Max size is 200 characters.
message = "&message=" + "Hey there!"

# Initializing the route
route = "&route=v3"

# Initializing the phone number. They must be of 10 digits India specific.
numbers = "&numbers=" + "9833835156"

# Creating a complete URL request
url = request + sender_id + message + route + numbers

# Initializing the payload and headers
payload={}
headers = {'authorization': 'rNS1cnUmiVpZH9XtGfk3bMJvRyAzeoTwQEOFK8C065glhsdB42UA0bkoRKfLcVYh9i1lxaJdwpsnBr8E'}

# Generating the response using POST method
response = requests.request("POST", url, headers=headers, data=payload)

# Printing the response
print(response.text)
# Out:
# {"status_code":999,"message":"You need to complete one transaction of 100 INR or more before using API route."}
